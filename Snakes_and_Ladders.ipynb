# %%
import random
from game import player

class Player:
    def __init__(self, name):
        self.name = name
        self.health = 10
        self.lives = 3
        self.items = []
        self.blanket_pieces = 3

        def death(self):
            print("We need to some code for what happens if the character loses all three lives")

class snakes_and_ladders():
    MAX_VAL = 50
    #hard coded snakes
    snakes = {
        8: 4,
        18: 1,
        26: 10,
        39: 25,
        49: 16,
    }
    #hard coded ladders
    ladders = {
        3: 20,
        7: 14,
        11: 28,
        15: 34,
        22: 37,
        38: 47,
    }
    
    def welcome_msg(self):
        msg = """
        Welcome to Snakes and Ladders.

    
        Rules:
          1. Both players begin at starting position. 
             Take turns rolling the dice. 
             Move forward the number of spaces shown on the dice.
          2. If you lands at the bottom of a ladder, you can move up to the top of the ladder.
          3. If you lands on the head of a snake, you must slide down to the bottom of the snake.
          4. The first player to get to the FINAL position is the winner.
    
        """
        print(msg)
        
    def roll(self):
        min = 1
        max = 6
        dice_value = random.randint(min, max)
        
    def roll_the_dice(self):
        self.player_roll = input("press r to roll the dice or q to quit")
        if player_roll == "r":
            print("you rolled a {dice_value}")
            
            
    def special_tile(self):
        if ladders(n):
            print ("It\'s a ladder, climb up")
            n = ladders[n]
        elif snakes(n):
            print ("It\'s a snake! go down")
            n = snakes[n]
        return dice_value
        
    def start(self):
        self.welcome_msg()

        player1_current_position = 0
        player2_current_position = 0

    while True:
        input_1 = input("\n" + " Hit r to roll dice: ")#here
        if input_1 == "r":
            print("\nRolling dice...")
            dice_value = self.roll_the_dice()
#         print("moving....") 
#         player1_current_position = old_
        quit = input("To quit type Q")
        if quit == "Q":
            break

#         input_2 = input("\n" + player2_name + ": " + random.choice(player_turn_text) + " Hit r to roll dice: ")
#         print("\nRolling dice...")
#         dice_value = get_dice_value()
#         print(player2_name + " moving....")


    
#     def snake_bite(player1_health, current_value, player_name):
#         print("\n" + random.choice(snake_bite).upper() + " ~~~~~~~~>")
#         print("\n" + player_name + " got a snake bite. Down from " + str(self.health) + " to " + str()#####\ )
snakes_and_ladders()

# %%
import random
# from game import player

class Player:
    def __init__(self):
        self.playerPos = 1
        self.updated_postion = 0 

#     def update_position(self, inPos):
#         self.playerPos = inPos
        
updated_postion = 5 
    def getPosition(self):
        return self.player_pos

class snakes_and_ladders(self):
        def __init__(self):
        self.player1Pos = 1
        self.sallyPos = 1
        self.updated_postion = 0 
        self.max_value = 20
        self.dice_value = 0
#         self.snake = {
#         8: 4,
#         18: 1,
#         26: 10,
#         39: 25,
#         49: 16,
#     }
#         self.ladder = {
#         3: 20,
#         6: 14,
#         11: 28,
#         15: 34,
#         17: 74,
#         22: 37,
#         38: 47,
#         }
    #hard coded snakes
    snakes = 
    #hard coded ladders
    ladders = 
    
    def welcome_msg(self):
        msg = """
        Welcome to Snakes and Ladders.

    
        Rules:
          1. Both players begin at starting position. 
             Take turns rolling the dice. 
             Move forward the number of spaces shown on the dice.
          2. If you lands at the bottom of a ladder, you can move up to the top of the ladder.
          3. If you lands on the head of a snake, you must slide down to the bottom of the snake.
          4. The first player to get to the FINAL position is the winner.
    
        """
        print(msg)
        
    def roll(self):
        min = 1
        max = 7
        return random.randint(min, max)
        
        
    def roll_the_dice(self):
        self.player_roll = input("press r to roll the dice or q to quit")
        if player_roll == "r":
            self.dice_value = self.roll()
            print("you rolled a {dice_value}")
            
            
#     def start(self):
#         self.welcome_msg()
#         player1_current_position = 0
#         player2_current_position = 0 
        
    def play(self):
        self.welcome_msg()
        player1Pos = self.dice_value
        self.sallyPos = random.randint(1,7)
        if player1Pos == 2 and player1Pos == 4 and player1Pos == 6:
            print("Your safe!")
        if player1Pos == 3:
            print("snake got ya")
            player1.health = player1.health - self.snake_dam 
        else: 
            player1Pos = 
            
            
            
            
    #who ever gets to 20 1st wins 
    #13, 7, 9 will send you back 3 spots
    #evens will bump you up 2 spots
    # 5, 9 12 snake will take health 
            
        
#         self.
            
         
#     def gameMaster(self):
#         global winner
#         if self.getPosition() == 50:
#                 print("Player %i is the Winner!" % self.player_pos())
#                 winner = True

#         if winner == False:
#             print("\n----Player %i Hit r to roll----" % self.player_pos())
#             roll = self.rollDice()
#             print("You rolled: %i" % roll)
#             movePlayer(update_posi, roll)
#             checkPosition(self.player_pos)
            
            
            
snakes_and_ladders.self.welcome_msg()
snakes_and_ladders.roll_the_dice()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-16b43a685fb8> in <module>
#      12         return self.player_pos
#      13
# ---> 14 class snakes_and_ladders(self, max_value):
#      15     self.max_value = 50
#      16     #hard coded snakes
#
# NameError: name 'self' is not defined

# %%
# roll dice
# move spaces
# snakes and ladders concept to work

# %%
print('hi')
